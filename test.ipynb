# %%
from tools.TextNormalizer import TextNormalizer
import pickle as pk
import os
import time
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lukas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open(os.path.join("temp", "dataset"), "rb") as f:
        dataset = pk.load(f)

text_normalizer = TextNormalizer()

for data_point in dataset[:]:
        try:
            data_point["Abstract Normalized"] = text_normalizer(
                data_point["Abstract"]
            )
        except KeyError:
            dataset.remove(data_point)

# %%
from algorithms.DynamicTopicModeling import DynamicTopicModeling as Algo

help(Algo)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lukas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Lukas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Lukas\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lukas\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Help on class DynamicTopicModeling in module algorithms.DynamicTopicModeling:
#
# class DynamicTopicModeling(builtins.object)
#  |  DynamicTopicModeling(tw: Union[tomotopy.TermWeight, int] = <TermWeight.ONE: 0>, min_cf: int = 0, min_df: int = 0, rm_top: int = 0, k: int = 1, t: int = 1, alpha_var: float = 0.1, eta_var: float = 0.1, phi_var: float = 0.1, lr_a: float = 0.01, lr_b: float = 0.1, lr_c: float = 0.55, seed: int = 42, corpus: Optional[tomotopy.utils.Corpus] = None, transform: Optional[Callable[[dict], dict]] = None, iter=10, freeze_topics=False, workers: int = 4, parallel: Union[int, tomotopy.ParallelScheme] = 1, callback_interval=10, callback=None, show_progress=False, n_timepoints: int = 10, **kwargs: Any) -> None
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, documents: List[Dict[str, Any]]) -> Dict[str, Any]
#  |      Makes the DynamicTopicModeling instance callable. Performs dynamic topic modeling on the provided documents.
#  |
#  |      :param documents: List of document dictionaries.
#  |      :return: Dictionary containing model results.
#  |
#  |  __init__(self, tw: Union[tomotopy.TermWeight, int] = <TermWeight.ONE: 0>, min_cf: int = 0, min_df: int = 0, rm_top: int = 0, k: int = 1, t: int = 1, alpha_var: float = 0.1, eta_var: float = 0.1, phi_var: float = 0.1, lr_a: float = 0.01, lr_b: float = 0.1, lr_c: float = 0.55, seed: int = 42, corpus: Optional[tomotopy.utils.Corpus] = None, transform: Optional[Callable[[dict], dict]] = None, iter=10, freeze_topics=False, workers: int = 4, parallel: Union[int, tomotopy.ParallelScheme] = 1, callback_interval=10, callback=None, show_progress=False, n_timepoints: int = 10, **kwargs: Any) -> None
#  |      DT Parameters
#  |
#  |      tw : Union[int, TermWeight]
#  |          term weighting scheme in TermWeight. The default value is TermWeight.ONE
#  |
#  |      min_cf : int
#  |          minimum collection frequency of words. Words with a smaller collection frequency than min_cf are excluded from the model. The default value is 0, which means no words are excluded.
#  |
#  |      min_df : int
#  |          minimum document frequency of words. Words with a smaller document frequency than min_df are excluded from the model. The default value is 0, which means no words are excluded
#  |
#  |      rm_top : int
#  |          the number of top words to be removed. If you want to remove too common words from model, you can set this value to 1 or more. The default value is 0, which means no top words are removed.
#  |
#  |      k : int
#  |          the number of topics between 1 ~ 32767
#  |
#  |      t : int
#  |          the number of timpoints
#  |
#  |      alpha_var : float
#  |          transition variance of alpha (per-document topic distribution)
#  |
#  |      eta_var : float
#  |          variance of eta (topic distribution of each document) from its alpha
#  |
#  |      phi_var : float
#  |          transition variance of phi (word distribution of each topic)
#  |
#  |      lr_a : float
#  |          shape parameter a greater than zero, for SGLD step size calculated as e_i = a * (b + i) ^ (-c)
#  |
#  |      lr_b : float
#  |          shape parameter b greater than or equal to zero, for SGLD step size calculated as e_i = a * (b + i) ^ (-c)
#  |
#  |      lr_c : float
#  |          shape parameter c with range (0.5, 1], for SGLD step size calculated as e_i = a * (b + i) ^ (-c)
#  |
#  |      seed : int
#  |          random seed. default value is a random number from std::random_device{} in C++
#  |
#  |      corpus : Corpus
#  |          a list of documents to be added into the model
#  |
#  |      transform : Callable[dict, dict]
#  |          a callable object to manipulate arbitrary keyword arguments for a specific topic model
#  |
#  |      Train Parameters
#  |
#  |      iter : int
#  |          the number of iterations of Gibbs-sampling
#  |
#  |      workers : int
#  |          an integer indicating the number of workers to perform samplings. If workers is 0, the number of cores in the system will be used.
#  |
#  |      parallel : Union[int, ParallelScheme]
#  |          the parallelism scheme for training. the default value is ParallelScheme.DEFAULT which means that tomotopy selects the best scheme by model.
#  |
#  |      freeze_topics : bool
#  |          prevents to create a new topic when training. Only valid for HLDAModel
#  |
#  |      callback_interval : int
#  |          the interval of calling callback function. If callback_interval <= 0, callback function is called at the beginning and the end of training.
#  |
#  |      callback : Callable[[LDAModel, int, int], None]
#  |          a callable object which is called every callback_interval iterations. It receives three arguments: the current model, the current number of iterations, and the total number of iterations.
#  |
#  |      show_progress : bool
#  |          If True, it shows progress bar during training using tqdm package.
#  |
#  |      General Parameters: int
#  |          Number of timepoints the data should be sprlit into
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
algo = Algo()

start_time = time.time()
results = algo(dataset)
end_time = time.time() - start_time

print("Algorithm Run took: ", end_time, "s ")
print("Results", results)
# Out:
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2016-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'NEW METHOD', 'RESULTS', 'COMPARISON WITH EXISTING METHOD (S)', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2016-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2014-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'INTERPRETATION', 'Copyright', 'Abstract Normalized'])
# 2014-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2014-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2014-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2013-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2013-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'CASE PRESENTATION', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND & AIMS', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2021-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'PURPOSE', 'MATERIAL AND METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'CLASSIFICATION OF EVIDENCE', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVES', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'APPLICATIONS', 'DISCUSSION', 'Copyright', 'Abstract Normalized'])
# 2021-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE OF REVIEW', 'RECENT FINDINGS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'MATERIALS AND METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2023-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'INTRODUCTION', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'INTRODUCTION', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'INTRODUCTION', 'AREAS COVERED', 'EXPERT OPINION', 'Copyright', 'Abstract Normalized'])
# 2020-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'SUBJECTS AND METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'INTRODUCTION', 'AREAS COVERED', 'EXPERT OPINION', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE OF REVIEW', 'RECENT FINDINGS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'INTRODUCTION', 'OBJECTIVE/HYPOTHESIS', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVES', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'CASE DESCRIPTION', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVES', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE OF REVIEW', 'RECENT FINDINGS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHOD', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'INTERPRETATION', 'Copyright', 'Abstract Normalized'])
# 2020-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'DISCUSSION', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'PARTICIPANTS', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE OF REVIEW', 'RECENT FINDINGS', 'SUMMARY', 'Copyright', 'Abstract Normalized'])
# 2018-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'OBJECTIVE', 'METHODS', 'RESULTS', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2020-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'NEW METHOD', 'RESULTS', 'COMPARISON WITH EXISTING METHODS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'PURPOSE', 'STUDY TYPE', 'POPULATION', 'FIELD STRENGTH/SEQUENCE', 'ASSESSMENT', 'STATISTICAL TESTS', 'RESULTS', 'DATA CONCLUSION', 'LEVEL OF EVIDENCE', 'Copyright', 'Abstract Normalized'])
# 2020-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE OF REVIEW', 'RECENT FINDINGS', 'SUMMARY', 'Copyright', 'Abstract Normalized'])
# 2019-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'AIMS', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2020-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE OF THE REVIEW', 'RECENT FINDINGS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'MATERIALS AND METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'MATERIALS AND METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2019-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2019-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2020-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-10-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE OF REVIEW', 'RECENT FINDINGS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'DISCUSSION/CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-07-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2018-09-01 00:00:00
# ...
# 2021-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'CASE PRESENTATION', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND AND PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'INTRODUCTION', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2021-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'AIM', 'MATERIAL AND METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2021-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2021-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'MATERIALS AND METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2021-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'EVIDENCE ACQUISITION', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'UNLABELLED', 'SIGNIFICANCE STATEMENT', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2015-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2019-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2018-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2017-12-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2018-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2018-02-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2017-06-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVES', 'MATERIALS AND METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2017-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2017-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2016-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2016-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2017-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'OBJECTIVES', 'DESIGN', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# 2024-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2024-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2024-05-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2024-03-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2024-04-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'PURPOSE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2023-11-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2023-09-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSION', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'BACKGROUND', 'OBJECTIVE', 'MATERIAL AND METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2022-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'METHODS', 'RESULTS', 'CONCLUSIONS', 'ADVANCES IN KNOWLEDGE', 'Copyright', 'Abstract Normalized'])
# 2022-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2022-08-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'OBJECTIVE', 'PATIENTS AND METHODS', 'RESULTS', 'CONCLUSIONS', 'Copyright', 'Abstract Normalized'])
# 2022-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2022-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# 2021-01-01 00:00:00
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# dict_keys(['PMID', 'Title', 'Abstract', 'Authors', 'PublicationDate', 'Keywords', 'Journal', 'Copyright', 'Abstract Normalized'])
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 algo = Algo()
#       3 start_time = time.time()
# ----> 4 results = algo(dataset)
#       5 end_time = time.time() - start_time
#       7 print("Algorithm Run took: ", end_time, "s ")
#
# File c:\Users\Lukas\PycharmProjects\clr-llm-agent\algorithms\DynamicTopicModeling.py:175, in DynamicTopicModeling.__call__(self, documents)
#     171     publication_date_parsed = self._parse_publication_date(document["PublicationDate"])
#     172     print(publication_date_parsed)
# --> 175 topics = self.get_topics(top_n=10)
#     176 result: Dict[str, Any] = {
#     177     "num_topics": self.num_topics,
#     178     "time_slices": self.time_slices,
#    (...)
#     187     "corpus": self.corpus,
#     188 }
#     189 return result
#
# AttributeError: 'DynamicTopicModeling' object has no attribute 'get_topics'

# %% [markdown]
# # Eigenes Experiment

# %%
import numpy as np
import matplotlib.pyplot as plt

def neural_network_demo(W1, W2, W3, b1, b2, b3, activation_function):
    # Initialize network parameters
    weights = [W1, W2, W3]
    biases = [b1, b2, b3]
 
    # Function to add a new hidden layer
    def add_layer(input_size, output_size):
        W_new = np.zeros((output_size, input_size))
        b_new = np.zeros((output_size, 1))
        weights.insert(-1, W_new)
        biases.insert(-1, b_new)
    
    # Function to add neurons to an existing layer
    def add_neurons(layer_index, num_neurons):
        input_size = weights[layer_index].shape[1]
        W_extra = np.zeros((num_neurons, input_size))
        b_extra = np.zeros((num_neurons, 1))
        weights[layer_index] = np.vstack([weights[layer_index], W_extra])
        biases[layer_index] = np.vstack([biases[layer_index], b_extra])
        # Adjust weights of the next layer
        weights[layer_index + 1] = np.hstack([weights[layer_index + 1], np.zeros((weights[layer_index + 1].shape[0], num_neurons))])
    
    # Forward pass function
    def forward(x):
        a = x.reshape(-1, 1)  # Convert to column vector
        for i in range(len(weights)):
            z = weights[i] @ a + biases[i]
            if i < len(weights) - 1:
                a = activation_function(z)
            else:
                a =  z
        print(a)
        return a
    
    
    # Perform grid search
    grid_size = 100  # Adjust grid size as needed
    x1 = np.linspace(-10, 10, grid_size)
    x2 = np.linspace(-10, 10, grid_size)
    X1, X2 = np.meshgrid(x1, x2)
    Y = np.zeros_like(X1)

    
    for i in range(grid_size):
        for j in range(grid_size):
            input_vec = np.array([X1[i, j], X2[i, j]])
            hidden_layer_output = forward(input_vec)
            Y[i, j] = hidden_layer_output
       
    
    # Plot the color contour
    plt.figure(figsize=(10, 8))
    contour = plt.contourf(X1, X2, Y , levels=100, cmap='viridis', alpha=0.8)
    plt.colorbar(contour, label='Output Scalar')
    
    # Overlay scatter plot with numerical annotations every 5 steps
    step = 5  # Adjust step to control density of annotations
    for i in range(0, grid_size, step):
        for j in range(0, grid_size, step):
            #plt.scatter(X1[i, j], X2[i, j], color='white', edgecolors='black', s=50)
            plt.text(X1[i, j], X2[i, j], f"{Y[i, j]:.2f}", color='black',
                     fontsize=8, ha='center', va='center')
    
    plt.xlabel('Input 1')
    plt.ylabel('Input 2')
    plt.title('Neural Network Output with Annotations')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.show()
    
    # Return parameters and utility functions for manual modification
    return {
        'weights': weights,
        'biases': biases,
        'add_layer': add_layer,
        'add_neurons': add_neurons,
        'forward': forward,
        'activation_function': activation_function
    }

# Define the activation function (ReLU)
def activation_function(x):
    return np.abs(x)
    #return np.maximum(0, x)
    # To use a different activation function, modify the above line or define a new function.

# Run the neural network demo multiple times
for run in range(1):
    # Initialize weights and biases with random values
    W1 = np.random.randn(2, 2)   
    b1 = np.random.randn(2, 1)
    W2 = np.random.randn(2, 2)
    b2 = np.random.randn(2, 1)
    W3 = np.random.randn(1, 2)
    b3 = np.random.randn(1, 1)
    
    print(f"Run {run + 1}/10")
    params = neural_network_demo(W1=W1, W2=W2, W3=W3, b2=b2, b3=b3, b1=b1, activation_function=activation_function)
    
    # Example of manually modifying weights and biases
    # Uncomment and modify as needed
    # params['weights'][0][0,0] = 1.0  # Modify first weight of first layer
    # params['biases'][2][0,0] = -0.5  # Modify bias of output layer
    
    # You can also add layers or neurons if needed
    # params['add_layer'](input_size=4, output_size=2)  # Add a new hidden layer with 2 neurons
    # params['add_neurons'](layer_index=0, num_neurons=2)  # Add 2 neurons to the first hidden layer
    
    print("Plot generated.\n")
